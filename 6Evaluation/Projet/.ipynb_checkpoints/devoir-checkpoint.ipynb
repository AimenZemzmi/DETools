# %% [markdown]
# Devoir Projet :
#
# - CSV = liste des musées en France

# %%
import pandas as pd
import pymongo
import datetime

# %%
client = pymongo.MongoClient("mongodb://so:sososo@cluster0-shard-00-00.10mhd.mongodb.net:27017,cluster0-shard-00-01.10mhd.mongodb.net:27017,cluster0-shard-00-02.10mhd.mongodb.net:27017/myFirstDatabase?ssl=true&replicaSet=atlas-1k8ffc-shard-0&authSource=admin&retryWrites=true&w=majority")
database = client['exercices']
collection = database['projet']

# %%
df_foot = pd.read_csv("./data/df_matches.csv", encoding = "ISO-8859-1")
df_foot.head(2)
# Out:
#                  X2                 X4   X5            X6 adversaire  \
# 0      1er mai 1904  Belgique - France  3-3  Match amical   Belgique
# 1  12 fÃ©vrier 1905    France - Suisse  1-0  Match amical     Suisse
#
#    score_france  score_adversaire  penalty_france  penalty_adversaire  \
# 0             3                 3             NaN                 NaN
# 1             1                 0             NaN                 NaN
#
#          date    year outcome  no
# 0  1904-05-01  1904.0    draw   1
# 1  1905-02-12  1905.0     win   1

# %% [markdown]
# # Netoyer les données

# %%
df_foot.rename(columns={'X2':'full_date'}, inplace=True)
df_foot.rename(columns={'X4':'match'}, inplace=True)
df_foot.rename(columns={'X5':'score'}, inplace=True)
df_foot.rename(columns={'X6':'type'}, inplace=True)
df_foot = df_foot.drop_duplicates(subset='date', keep='last')
l_d = df_foot.to_dict(orient='records')

# %% [markdown]
# # Importer les données

# %%
collection.delete_many({})
collection.insert_many(l_d)

# %% [markdown]
# # Requête 1 :

# %%
req = collection.find()
next(req)
# Out:
# {'_id': ObjectId('602e81816ed2db099b99d85d'),
#  'full_date': '1er mai 1904',
#  'match': 'Belgique - France',
#  'score': '3-3',
#  'type': 'Match amical',
#  'adversaire': 'Belgique',
#  'score_france': 3,
#  'score_adversaire': 3,
#  'penalty_france': nan,
#  'penalty_adversaire': nan,
#  'date': '1904-05-01',
#  'year': 1904.0,
#  'outcome': 'draw',
#  'no': 1}

# %% [markdown]
# # Requête 2 :

# %% [markdown]
# Liste des confrontations avec un pays :
#  - Avec un exemple la Belgique

# %%
req = collection.find({"adversaire":"Belgique"})
list(req)
# Out:
# [{'_id': ObjectId('602e81816ed2db099b99d85d'),
#   'full_date': '1er mai 1904',
#   'match': 'Belgique - France',
#   'score': '3-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1904-05-01',
#   'year': 1904.0,
#   'outcome': 'draw',
#   'no': 1},
#  {'_id': ObjectId('602e81816ed2db099b99d85f'),
#   'full_date': '7 mai 1905',
#   'match': 'Belgique - France',
#   'score': '7-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 7,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1905-05-07',
#   'year': 1905.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e81816ed2db099b99d860'),
#   'full_date': '22 avril 1906',
#   'match': 'France - Belgique',
#   'score': '0-5',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 5,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1906-04-22',
#   'year': 1906.0,
#   'outcome': 'loss',
#   'no': 1},
#  {'_id': ObjectId('602e81816ed2db099b99d862'),
#   'full_date': '21 avril 1907',
#   'match': 'Belgique - France',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1907-04-21',
#   'year': 1907.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e81816ed2db099b99d865'),
#   'full_date': '12 avril 1908',
#   'match': 'France - Belgique',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1908-04-12',
#   'year': 1908.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602e81816ed2db099b99d868'),
#   'full_date': '8 mai 1909',
#   'match': 'Belgique - France',
#   'score': '5-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 5,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1909-05-08',
#   'year': 1909.0,
#   'outcome': 'loss',
#   'no': 1},
#  {'_id': ObjectId('602e81816ed2db099b99d86a'),
#   'full_date': '3 avril 1910',
#   'match': 'France - Belgique',
#   'score': '0-4',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1910-04-03',
#   'year': 1910.0,
#   'outcome': 'loss',
#   'no': 1},
#  {'_id': ObjectId('602e81816ed2db099b99d871'),
#   'full_date': '30 avril 1911',
#   'match': 'Belgique - France',
#   'score': '7-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 7,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1911-04-30',
#   'year': 1911.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602e81816ed2db099b99d873'),
#   'full_date': '28 janvier 1912',
#   'match': 'France - Belgique',
#   'score': '1-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1912-01-28',
#   'year': 1912.0,
#   'outcome': 'draw',
#   'no': 1},
#  {'_id': ObjectId('602e81816ed2db099b99d877'),
#   'full_date': '16 fÃ©vrier 1913',
#   'match': 'Belgique - France',
#   'score': '3-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1913-02-16',
#   'year': 1913.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e81816ed2db099b99d87b'),
#   'full_date': '25 janvier 1914',
#   'match': 'France - Belgique',
#   'score': '4-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 4,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1914-01-25',
#   'year': 1914.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e81816ed2db099b99d880'),
#   'full_date': '9 mars 1919',
#   'match': 'Belgique - France',
#   'score': '2-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1919-03-09',
#   'year': 1919.0,
#   'outcome': 'draw',
#   'no': 1},
#  {'_id': ObjectId('602e81816ed2db099b99d883'),
#   'full_date': '28 mars 1920',
#   'match': 'France - Belgique',
#   'score': '2-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1920-03-28',
#   'year': 1920.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e81816ed2db099b99d889'),
#   'full_date': '6 mars 1921',
#   'match': 'Belgique - France',
#   'score': '3-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1921-03-06',
#   'year': 1921.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602e81816ed2db099b99d88c'),
#   'full_date': '15 janvier 1922',
#   'match': 'France - Belgique',
#   'score': '2-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1922-01-15',
#   'year': 1922.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e81816ed2db099b99d88f'),
#   'full_date': '25 fÃ©vrier 1923',
#   'match': 'Belgique - France',
#   'score': '4-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1923-02-25',
#   'year': 1923.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e81816ed2db099b99d894'),
#   'full_date': '13 janvier 1924',
#   'match': 'France - Belgique',
#   'score': '2-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1924-01-13',
#   'year': 1924.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e81816ed2db099b99d89a'),
#   'full_date': '11 novembre 1924',
#   'match': 'Belgique - France',
#   'score': '3-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1924-11-11',
#   'year': 1924.0,
#   'outcome': 'loss',
#   'no': 7},
#  {'_id': ObjectId('602e81816ed2db099b99d89e'),
#   'full_date': '11 avril 1926',
#   'match': 'France - Belgique',
#   'score': '4-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 4,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1926-04-11',
#   'year': 1926.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e81816ed2db099b99d8a3'),
#   'full_date': '20 juin 1926',
#   'match': 'Belgique - France',
#   'score': '2-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1926-06-20',
#   'year': 1926.0,
#   'outcome': 'draw',
#   'no': 6},
#  {'_id': ObjectId('602e81816ed2db099b99d8ab'),
#   'full_date': '15 avril 1928',
#   'match': 'France - Belgique',
#   'score': '2-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1928-04-15',
#   'year': 1928.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602e81816ed2db099b99d8b5'),
#   'full_date': '26 mai 1929',
#   'match': 'Belgique - France',
#   'score': '4-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1929-05-26',
#   'year': 1929.0,
#   'outcome': 'loss',
#   'no': 6},
#  {'_id': ObjectId('602e81816ed2db099b99d8b8'),
#   'full_date': '13 avril 1930',
#   'match': 'France - Belgique',
#   'score': '1-6',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 6,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1930-04-13',
#   'year': 1930.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602e81816ed2db099b99d8bb'),
#   'full_date': '25 mai 1930',
#   'match': 'Belgique - France',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1930-05-25',
#   'year': 1930.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602e81816ed2db099b99d8bf'),
#   'full_date': '7 dÃ©cembre 1930',
#   'match': 'France - Belgique',
#   'score': '2-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1930-12-07',
#   'year': 1930.0,
#   'outcome': 'draw',
#   'no': 10},
#  {'_id': ObjectId('602e81816ed2db099b99d8c7'),
#   'full_date': '1er mai 1932',
#   'match': 'Belgique - France',
#   'score': '5-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 5,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1932-05-01',
#   'year': 1932.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602e81816ed2db099b99d8ce'),
#   'full_date': '26 mars 1933',
#   'match': 'France - Belgique',
#   'score': '3-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1933-03-26',
#   'year': 1933.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e81816ed2db099b99d8d3'),
#   'full_date': '21 janvier 1934',
#   'match': 'Belgique - France',
#   'score': '2-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1934-01-21',
#   'year': 1934.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e81816ed2db099b99d8dd'),
#   'full_date': '14 avril 1935',
#   'match': 'Belgique - France',
#   'score': '1-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1935-04-14',
#   'year': 1935.0,
#   'outcome': 'draw',
#   'no': 4},
#  {'_id': ObjectId('602e81816ed2db099b99d8e3'),
#   'full_date': '8 mars 1936',
#   'match': 'France - Belgique',
#   'score': '3-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1936-03-08',
#   'year': 1936.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e81816ed2db099b99d8e6'),
#   'full_date': '21 fÃ©vrier 1937',
#   'match': 'Belgique - France',
#   'score': '3-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1937-02-21',
#   'year': 1937.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e81816ed2db099b99d8ec'),
#   'full_date': '30 janvier 1938',
#   'match': 'France - Belgique',
#   'score': '5-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 5,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1938-01-30',
#   'year': 1938.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e81816ed2db099b99d8ef'),
#   'full_date': '5 juin 1938',
#   'match': 'France - Belgique',
#   'score': '3-1',
#   'type': 'Coupe du monde 1938 (HuitiÃ¨me de finale)',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1938-06-05',
#   'year': 1938.0,
#   'outcome': 'win',
#   'no': 4},
#  {'_id': ObjectId('602e81816ed2db099b99d8f4'),
#   'full_date': '18 mai 1939',
#   'match': 'Belgique - France',
#   'score': '1-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1939-05-18',
#   'year': 1939.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e81816ed2db099b99d8f9'),
#   'full_date': '24 dÃ©cembre 1944',
#   'match': 'France - Belgique',
#   'score': '3-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1944-12-24',
#   'year': 1944.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e81816ed2db099b99d8fd'),
#   'full_date': '15 dÃ©cembre 1945',
#   'match': 'Belgique - France',
#   'score': '2-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1945-12-15',
#   'year': 1945.0,
#   'outcome': 'loss',
#   'no': 4},
#  {'_id': ObjectId('602e81816ed2db099b99d905'),
#   'full_date': '1er juin 1947',
#   'match': 'France - Belgique',
#   'score': '4-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 4,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1947-06-01',
#   'year': 1947.0,
#   'outcome': 'win',
#   'no': 4},
#  {'_id': ObjectId('602e81816ed2db099b99d90a'),
#   'full_date': '6 juin 1948',
#   'match': 'Belgique - France',
#   'score': '4-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1948-06-06',
#   'year': 1948.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602e81816ed2db099b99d90c'),
#   'full_date': '17 octobre 1948',
#   'match': 'France - Belgique',
#   'score': '3-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1948-10-17',
#   'year': 1948.0,
#   'outcome': 'draw',
#   'no': 5},
#  {'_id': ObjectId('602e81816ed2db099b99d917'),
#   'full_date': '4 juin 1950',
#   'match': 'Belgique - France',
#   'score': '4-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1950-06-04',
#   'year': 1950.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e81816ed2db099b99d918'),
#   'full_date': '1er novembre 1950',
#   'match': 'France - Belgique',
#   'score': '3-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1950-11-01',
#   'year': 1950.0,
#   'outcome': 'draw',
#   'no': 3},
#  {'_id': ObjectId('602e81816ed2db099b99d923'),
#   'full_date': '22 mai 1952',
#   'match': 'Belgique - France',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1952-05-22',
#   'year': 1952.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e81816ed2db099b99d928'),
#   'full_date': '25 dÃ©cembre 1952',
#   'match': 'France - Belgique',
#   'score': '0-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1952-12-25',
#   'year': 1952.0,
#   'outcome': 'loss',
#   'no': 8},
#  {'_id': ObjectId('602e81816ed2db099b99d932'),
#   'full_date': '30 mai 1954',
#   'match': 'Belgique - France',
#   'score': '3-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1954-05-30',
#   'year': 1954.0,
#   'outcome': 'draw',
#   'no': 2},
#  {'_id': ObjectId('602e81816ed2db099b99d936'),
#   'full_date': '11 novembre 1954',
#   'match': 'France - Belgique',
#   'score': '2-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1954-11-11',
#   'year': 1954.0,
#   'outcome': 'draw',
#   'no': 6},
#  {'_id': ObjectId('602e81816ed2db099b99d93d'),
#   'full_date': '25 dÃ©cembre 1955',
#   'match': 'Belgique - France',
#   'score': '2-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1955-12-25',
#   'year': 1955.0,
#   'outcome': 'loss',
#   'no': 7},
#  {'_id': ObjectId('602e81816ed2db099b99d942'),
#   'full_date': '11 novembre 1956',
#   'match': 'France - Belgique',
#   'score': '6-3',
#   'type': 'Qualifications pour la Coupe du monde 1958',
#   'adversaire': 'Belgique',
#   'score_france': 6,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1956-11-11',
#   'year': 1956.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602e81816ed2db099b99d947'),
#   'full_date': '27 octobre 1957',
#   'match': 'Belgique - France',
#   'score': '0-0',
#   'type': 'Qualifications pour la Coupe du monde 1958',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1957-10-27',
#   'year': 1957.0,
#   'outcome': 'draw',
#   'no': 5},
#  {'_id': ObjectId('602e81816ed2db099b99d957'),
#   'full_date': '1er mars 1959',
#   'match': 'France - Belgique',
#   'score': '2-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1959-03-01',
#   'year': 1959.0,
#   'outcome': 'draw',
#   'no': 1},
#  {'_id': ObjectId('602e81816ed2db099b99d95c'),
#   'full_date': '28 fÃ©vrier 1960',
#   'match': 'Belgique - France',
#   'score': '1-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1960-02-28',
#   'year': 1960.0,
#   'outcome': 'loss',
#   'no': 1},
#  {'_id': ObjectId('602e81816ed2db099b99d966'),
#   'full_date': '15 mars 1961',
#   'match': 'France - Belgique',
#   'score': '1-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1961-03-15',
#   'year': 1961.0,
#   'outcome': 'draw',
#   'no': 1},
#  {'_id': ObjectId('602e81816ed2db099b99d969'),
#   'full_date': '18 octobre 1961',
#   'match': 'Belgique - France',
#   'score': '3-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1961-10-18',
#   'year': 1961.0,
#   'outcome': 'loss',
#   'no': 4},
#  {'_id': ObjectId('602e81816ed2db099b99d979'),
#   'full_date': '25 dÃ©cembre 1963',
#   'match': 'France - Belgique',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1963-12-25',
#   'year': 1963.0,
#   'outcome': 'loss',
#   'no': 8},
#  {'_id': ObjectId('602e81816ed2db099b99d97e'),
#   'full_date': '2 dÃ©cembre 1964',
#   'match': 'Belgique - France',
#   'score': '3-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1964-12-02',
#   'year': 1964.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602e81816ed2db099b99d986'),
#   'full_date': '20 avril 1966',
#   'match': 'France - Belgique',
#   'score': '0-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1966-04-20',
#   'year': 1966.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e81816ed2db099b99d98d'),
#   'full_date': '11 novembre 1966',
#   'match': 'Belgique - France',
#   'score': '2-1',
#   'type': "Qualifications pour l'Euro 1968",
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1966-11-11',
#   'year': 1966.0,
#   'outcome': 'loss',
#   'no': 9},
#  {'_id': ObjectId('602e81816ed2db099b99d993'),
#   'full_date': '28 octobre 1967',
#   'match': 'France - Belgique',
#   'score': '1-1',
#   'type': "Qualifications pour l'Euro 1968",
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1967-10-28',
#   'year': 1967.0,
#   'outcome': 'draw',
#   'no': 5},
#  {'_id': ObjectId('602e81816ed2db099b99d9a5'),
#   'full_date': '15 novembre 1970',
#   'match': 'Belgique - France',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1970-11-15',
#   'year': 1970.0,
#   'outcome': 'win',
#   'no': 7},
#  {'_id': ObjectId('602e81816ed2db099b99d9c0'),
#   'full_date': '12 octobre 1974',
#   'match': 'Belgique - France',
#   'score': '2-1',
#   'type': "Qualifications pour l'Euro 1976",
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1974-10-12',
#   'year': 1974.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602e81816ed2db099b99d9c7'),
#   'full_date': '15 novembre 1975',
#   'match': 'France - Belgique',
#   'score': '0-0',
#   'type': "Qualifications pour l'Euro 1976",
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1975-11-15',
#   'year': 1975.0,
#   'outcome': 'draw',
#   'no': 6},
#  {'_id': ObjectId('602e81816ed2db099b99d9ee'),
#   'full_date': '29 avril 1981',
#   'match': 'France - Belgique',
#   'score': '3-2',
#   'type': 'Qualifications pour la Coupe du monde 1982',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1981-04-29',
#   'year': 1981.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e81816ed2db099b99d9f0'),
#   'full_date': '9 septembre 1981',
#   'match': 'Belgique - France',
#   'score': '2-0',
#   'type': 'Qualifications pour la Coupe du monde 1982',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1981-09-09',
#   'year': 1981.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602e81816ed2db099b99da06'),
#   'full_date': '31 mai 1983',
#   'match': 'Belgique - France[29]',
#   'score': '1-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1983-05-31',
#   'year': 1983.0,
#   'outcome': 'draw',
#   'no': 4},
#  {'_id': ObjectId('602e81816ed2db099b99da0f'),
#   'full_date': '16 juin 1984',
#   'match': 'France - Belgique',
#   'score': '5-0',
#   'type': 'Euro 1984 (Groupe A)',
#   'adversaire': 'Belgique',
#   'score_france': 5,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1984-06-16',
#   'year': 1984.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602e81816ed2db099b99da24'),
#   'full_date': '28 juin 1986',
#   'match': 'France - Belgique',
#   'score': '4-2',
#   'type': 'Coupe du monde 1986 (Petite finale)',
#   'adversaire': 'Belgique',
#   'score_france': 4,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1986-06-28',
#   'year': 1986.0,
#   'outcome': 'win',
#   'no': 9},
#  {'_id': ObjectId('602e81816ed2db099b99da4e'),
#   'full_date': '25 mars 1992',
#   'match': 'France - Belgique',
#   'score': '3-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1992-03-25',
#   'year': 1992.0,
#   'outcome': 'draw',
#   'no': 2},
#  {'_id': ObjectId('602e81816ed2db099b99da74'),
#   'full_date': '27 mars 1996',
#   'match': 'Belgique - France',
#   'score': '0-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1996-03-27',
#   'year': 1996.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e81816ed2db099b99da8c'),
#   'full_date': '27 mai 1998',
#   'match': 'France - Belgique',
#   'score': '1-0',
#   'type': 'Tournoi Hassan II 1998 (amical)',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1998-05-27',
#   'year': 1998.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602e81816ed2db099b99dac6'),
#   'full_date': '18 mai 2002',
#   'match': 'France - Belgique',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2002-05-18',
#   'year': 2002.0,
#   'outcome': 'loss',
#   'no': 4},
#  {'_id': ObjectId('602e81816ed2db099b99dade'),
#   'full_date': '18 fÃ©vrier 2004',
#   'match': 'Belgique - France',
#   'score': '0-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2004-02-18',
#   'year': 2004.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e81816ed2db099b99db48'),
#   'full_date': '15 novembre 2011',
#   'match': 'France - Belgique',
#   'score': '0-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2011-11-15',
#   'year': 2011.0,
#   'outcome': 'draw',
#   'no': 13},
#  {'_id': ObjectId('602e81816ed2db099b99db5c'),
#   'full_date': '14 aoÃ»t 2013',
#   'match': 'Belgique - France',
#   'score': '0-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2013-08-14',
#   'year': 2013.0,
#   'outcome': 'draw',
#   'no': 6},
#  {'_id': ObjectId('602e81816ed2db099b99db74'),
#   'full_date': '7 juin 2015',
#   'match': 'France - Belgique',
#   'score': '3-4',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2015-06-07',
#   'year': 2015.0,
#   'outcome': 'loss',
#   'no': 3}]

# %% [markdown]
# # Requête 3 :

# %% [markdown]
# La même chose que précedemment mais avec une période de 2010 - 2018

# %%
from_date = datetime.datetime(2010, 12, 31, 12, 30, 30, 125000) 
to_date = datetime.datetime(2011, 12, 31, 12, 30, 30, 125000) 
    
req = collection.find({{"adversaire":"Belgique"}, {"date": {"$gte": from_date, "$lt": to_date}}})
list(req)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-dbe338730386> in <module>
#       2 to_date = datetime.datetime(2011, 12, 31, 12, 30, 30, 125000)
#       3
# ----> 4 req = collection.find({{"adversaire":"Belgique"}, {"date": {"$gte": from_date, "$lt": to_date}}})
#       5 list(req)
#
# TypeError: unhashable type: 'dict'

# %% [markdown]
# # Requête 4 :
